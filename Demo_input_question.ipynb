# %%
# !pip uninstall scikit-learn
# !pip install --upgrade scikit-learn
import sklearn
print(sklearn.__version__)
# !pip install scikit-multilearn
# !pip install scikit-learn
# !pip install --upgrade scikit-learn
# !pip install --upgrade scikit-learn
from sklearn.multioutput import ClassifierChain
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd
import numpy as np
import re
import nltk
##import spacy
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %matplotlib inline
pd.set_option('display.max_colwidth', 200)

##import tensorflow as tf
##from tensorflow import keras

import nltk
nltk.download('all')



from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from scipy.sparse import hstack

from sklearn.metrics import accuracy_score
from sklearn.svm import LinearSVC
from sklearn.metrics import hamming_loss
from sklearn.metrics import f1_score
from skmultilearn.problem_transform import LabelPowerset
from sklearn.linear_model import SGDClassifier
#from sklearn.naive_bayes import GaussianNB
from sklearn import svm
#from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import jaccard_score
##error from sklearn.metrics import jaccard_similarity_score
from sklearn import model_selection
from sklearn.metrics import make_scorer
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
# Out:
# Found existing installation: scikit-learn 1.4.1.post1
# Uninstalling scikit-learn-1.4.1.post1:
#   Would remove:
#     /usr/local/lib/python3.10/dist-packages/scikit_learn-1.4.1.post1.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/scikit_learn.libs/libgomp-a34b3233.so.1.0.0
#     /usr/local/lib/python3.10/dist-packages/sklearn/*
# Proceed (Y/n)? y
#   Successfully uninstalled scikit-learn-1.4.1.post1
# ...
#   Using cached scikit_learn-1.4.1.post1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
# ...
# 1.4.1.post1
# ...
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

FOLDERNAME = 'archive'


import sys
sys.path.append('/drive/My Drive/{}'.format(FOLDERNAME))


# %cd /content/drive/My\ Drive/$FOLDERNAME/

df_questions = pd.read_csv("/content/drive/MyDrive/archive/Questions.csv", encoding="ISO-8859-1")
df_tags = pd.read_csv("/content/drive/MyDrive/archive/Tags.csv", encoding="ISO-8859-1", dtype={'Tag': str})


df_questions.head()
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/archive
#     Id  OwnerUserId          CreationDate            ClosedDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z                   NaN     26
# 1   90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z    144
# 2  120         83.0  2008-08-01T15:50:08Z                   NaN     21
# 3  180    2089740.0  2008-08-01T18:42:19Z                   NaN     53
# 4  260         91.0  2008-08-01T23:22:08Z                   NaN     49
#
#                                                         Title  \
# 0  SQLStatement.execute() - multiple queries in one statement
# 1       Good branching and merging tutorials for TortoiseSVN?
# 2                                           ASP.NET Site Maps
# 3                          Function for creating color wheels
# 4         Adding scripting functionality to .NET applications
#
# ...

# %%
##file_path = r"C:\Users\lenovo\Downloads\archive\Tags.csv"
##data = pd.read_csv("/content/drive/MyDrive/archive/Questions.csv",encoding="ISO-8859-1")
##data.head()

# %%
# Read CSV files to get questions and tags
# Read CSV files to get questions and tags
df_questions = pd.read_csv("/content/drive/MyDrive/archive/Questions.csv", encoding="ISO-8859-1")
df_tags = pd.read_csv("/content/drive/MyDrive/archive/Tags.csv", encoding="ISO-8859-1", dtype={'Tag': str})


df_questions.head()
# Out:
#     Id  OwnerUserId          CreationDate            ClosedDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z                   NaN     26
# 1   90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z    144
# 2  120         83.0  2008-08-01T15:50:08Z                   NaN     21
# 3  180    2089740.0  2008-08-01T18:42:19Z                   NaN     53
# 4  260         91.0  2008-08-01T23:22:08Z                   NaN     49
#
#                                                         Title  \
# 0  SQLStatement.execute() - multiple queries in one statement
# 1       Good branching and merging tutorials for TortoiseSVN?
# 2                                           ASP.NET Site Maps
# 3                          Function for creating color wheels
# 4         Adding scripting functionality to .NET applications
#
# ...

# %% [markdown]
# Process tags
# Process them tags into something nice to query

# %%
# Group tags by id and join them
df_tags['Tag'] = df_tags['Tag'].astype(str)
grouped_tags = df_tags.groupby("Id")['Tag'].apply(lambda tags: ' '.join(tags))
grouped_tags.head(5)
# Out:
# Id
# 80                            flex actionscript-3 air
# 90       svn tortoisesvn branch branching-and-merging
# 120                               sql asp.net sitemap
# 180    algorithm language-agnostic colors color-space
# 260           c# .net scripting compiler-construction
# Name: Tag, dtype: object

# %%
# Reset index for making simpler dataframe
grouped_tags.reset_index()
grouped_tags_final = pd.DataFrame({'Id':grouped_tags.index, 'Tags':grouped_tags.values})
grouped_tags_final.head(5)
# Out:
#     Id                                            Tags
# 0   80                         flex actionscript-3 air
# 1   90    svn tortoisesvn branch branching-and-merging
# 2  120                             sql asp.net sitemap
# 3  180  algorithm language-agnostic colors color-space
# 4  260         c# .net scripting compiler-construction

# %%
# Drop unnecessary columns
##error df_questions.drop(columns=['OwnerUserId', 'CreationDate', 'ClosedDate'], inplace=True)

# Merge questions and tags into one dataframe
df = df_questions.merge(grouped_tags_final, on='Id')
df.head(5)
# Out:
#     Id  OwnerUserId          CreationDate            ClosedDate  Score  \
# 0   80         26.0  2008-08-01T13:57:07Z                   NaN     26
# 1   90         58.0  2008-08-01T14:41:24Z  2012-12-26T03:45:49Z    144
# 2  120         83.0  2008-08-01T15:50:08Z                   NaN     21
# 3  180    2089740.0  2008-08-01T18:42:19Z                   NaN     53
# 4  260         91.0  2008-08-01T23:22:08Z                   NaN     49
#
#                                                         Title  \
# 0  SQLStatement.execute() - multiple queries in one statement
# 1       Good branching and merging tutorials for TortoiseSVN?
# 2                                           ASP.NET Site Maps
# 3                          Function for creating color wheels
# 4         Adding scripting functionality to .NET applications
#
# ...

# %%
# Filter out questions with a score lower than 5
new_df = df[df['Score']>5]

# Split tags in order to get a list of tags
new_df['Tags'] = new_df['Tags'].apply(lambda x: x.split())
all_tags = [item for sublist in new_df['Tags'].values for item in sublist]

flat_list = [item for sublist in new_df['Tags'].values for item in sublist]

keywords = nltk.FreqDist(flat_list)
keywords = nltk.FreqDist(keywords)

# Get most frequent tags
frequencies_words = keywords.most_common(25)
tags_features = [word[0] for word in frequencies_words]
# Drop unnecessary columns at this point
new_df.drop(columns=['Id', 'Score'], inplace=True)
print(tags_features)
# Out:
# ['c#', 'java', 'javascript', 'android', 'python', 'c++', 'php', 'jquery', '.net', 'ios', 'html', 'css', 'c', 'iphone', 'objective-c', 'ruby-on-rails', 'sql', 'asp.net', 'mysql', 'ruby', 'r', 'git', 'asp.net-mvc', 'linux', 'sql-server']
# <ipython-input-7-7ca418de6e76>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Tags'] = new_df['Tags'].apply(lambda x: x.split())
# <ipython-input-7-7ca418de6e76>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=['Id', 'Score'], inplace=True)

# %%
def most_common(tags):
    """Function to check if tag is in most common tag list"""
    tags_filtered = []
    for i in range(0, len(tags)):
        if tags[i] in tags_features:
            tags_filtered.append(tags[i])
    return tags_filtered

# Change Tags column into None for questions that don't have a most common tag
new_df['Tags'] = new_df['Tags'].apply(lambda x: most_common(x))
new_df['Tags'] = new_df['Tags'].apply(lambda x: x if len(x)>0 else None)

# Drop rows that contain None in Tags column
new_df.dropna(subset=['Tags'], inplace=True)
new_df.shape
# Out:
# <ipython-input-8-272c9f00e26a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Tags'] = new_df['Tags'].apply(lambda x: most_common(x))
# <ipython-input-8-272c9f00e26a>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Tags'] = new_df['Tags'].apply(lambda x: x if len(x)>0 else None)
# <ipython-input-8-272c9f00e26a>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %% [markdown]
# Preprocess Data¶
# Remove special characters from title and body
# Remove stop words
# Remove HTML tags
# Convert characters to lowercase
# Lemmatize the words

# %%
from bs4 import BeautifulSoup
import lxml
import re
from nltk.corpus import stopwords
from nltk.tokenize import ToktokTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
#  # Filter out HTML
new_df['Body'] = new_df['Body'].apply(lambda x: BeautifulSoup(x, "lxml").get_text())
token  = ToktokTokenizer()
lemma = WordNetLemmatizer()
stop_words = set(stopwords.words("english"))
def strip_list_noempty(mylist):
    newlist = (item.strip() if hasattr(item, 'strip') else item for item in mylist)
    return [item for item in newlist if item != '']

def removeStopWords(text):
    words = token.tokenize(text)
    filtered = [w for w in words if not w in stop_words]
    return ' '.join(map(str, filtered))


def removePunctuation(text):
    punct = '!"$%&\'()*,./:;<=>?@[\\]^_`{|}~'
    words=token.tokenize(text)
    punctuation_filtered = []
    regex = re.compile('[%s]' % re.escape(punct))
    remove_punctuation = str.maketrans(' ', ' ', punct)
    for w in words:
        if w in tags_features:
            punctuation_filtered.append(w)
        else:
            punctuation_filtered.append(regex.sub('', w))

    filtered_list = strip_list_noempty(punctuation_filtered)
    return ' '.join(map(str, filtered_list))

def lemmatizeWords(text):
    words=token.tokenize(text)
    listLemma=[]
    for w in words:
        x=lemma.lemmatize(w, pos="v")
        listLemma.append(x.lower())
    return ' '.join(map(str, listLemma))


# Remove stopwords, punctuation and lemmatize for text in body
new_df['Body'] = new_df['Body'].apply(lambda x: removeStopWords(x))
new_df['Body'] = new_df['Body'].apply(lambda x: removePunctuation(x))
new_df['Body'] = new_df['Body'].apply(lambda x: lemmatizeWords(x))

# Remove stopwords, punctuation and lemmatize for title. Also weight title 3 times
new_df['Title'] = new_df['Title'].apply(lambda x: str(x))
new_df['Title'] = new_df['Title'].apply(lambda x: removePunctuation(x))
new_df['Title'] = new_df['Title'].apply(lambda x: removeStopWords(x))
new_df['Title'] = new_df['Title'].apply(lambda x: lemmatizeWords(x))
new_df['Title'] = new_df['Title'].apply(lambda x: ' '.join(x.split()*3))
new_df['Title']
# Out:
# <ipython-input-9-f1234c7cbe2f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Body'] = new_df['Body'].apply(lambda x: BeautifulSoup(x, "lxml").get_text())
# <ipython-input-9-f1234c7cbe2f>:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Body'] = new_df['Body'].apply(lambda x: removeStopWords(x))
# <ipython-input-9-f1234c7cbe2f>:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# # **Classifier implementation**

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score, recall_score, precision_score, hamming_loss, f1_score
from sklearn.model_selection import KFold
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from scipy.sparse import hstack
from skmultilearn.problem_transform import LabelPowerset
from sklearn.model_selection import train_test_split
import numpy as np

# Define X, y
X1 = new_df['Body']
X2 = new_df['Title']
y = new_df['Tags']

# Define multilabel binarizer
multilabel_binarizer = MultiLabelBinarizer()
y_bin = multilabel_binarizer.fit_transform(y)

vectorizer_X1 = TfidfVectorizer(analyzer='word',
                                min_df=0.0005,
                                max_df=1.0,
                                strip_accents=None,
                                encoding='utf-8',
                                ngram_range=(1, 3),
                                preprocessor=None,
                                token_pattern=r"(?u)\S\S+",
                                max_features=35000)

vectorizer_X2 = TfidfVectorizer(analyzer='word',
                                min_df=0.0,
                                max_df=1.0,
                                strip_accents=None,
                                encoding='utf-8',
                                ngram_range=(1, 3),
                                preprocessor=None,
                                token_pattern=r"(?u)\S\S+",
                                max_features=35000)

X1_tfidf = vectorizer_X1.fit_transform(X1)
X2_tfidf = vectorizer_X2.fit_transform(X2)

# Stack X1 and X2 into X_tfidf

# %% [markdown]
# **clssifieir chains**

# %%
# Using Classifier Chains
from sklearn.multioutput import ClassifierChain
import numpy as np


chains = [ClassifierChain(svc, order='random', random_state=i)
          for i in range(10)]

for chain in chains:
    chain.fit(X_train, y_train)

Y_pred_chains = np.array([chain.predict(X_test) for chain in
                          chains])

Y_pred_ensemble = Y_pred_chains.mean(axis=0)
ensemble_accuracy_score = accuracy_score(y_test, Y_pred_ensemble >= .5)
ensemble_recall_score = recall_score(y_test, Y_pred_ensemble >= .5, average='weighted')
ensemble_precision_score = precision_score(y_test, Y_pred_ensemble >= .5, average='weighted')
ensemble_f1_score = f1_score(y_pred, Y_pred_ensemble >= .5, average='weighted')
hamm = hamming_loss(Y_pred_ensemble >= .5, y_test)*100
print(ensemble_accuracy_score, ensemble_recall_score, ensemble_precision_score, ensemble_f1_score, hamm)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# ...

# %%
# Printing 10 test data points and their predicted tags
print("\nPrinting 10 Test Data Points and Their Predicted Tags:")
for i in range(10):
    print("Test Data Point:", X_test[i])
    print("Actual Tags:", [multilabel_binarizer.classes_[j] for j in range(len(y_test[i])) if y_test[i][j] == 1])
    print("Body:", new_df.iloc[X_test.indices[i]]['Body'])  # Assuming 'Body' is the column containing the body of questions
    print("Predicted Tags:", [multilabel_binarizer.classes_[j] for j in range(len(Y_pred_ensemble[i])) if Y_pred_ensemble[i][j] >= 0.5])
# Out:
# Printing 10 Test Data Points and Their Predicted Tags:
# Test Data Point:   (0, 6644)	0.10986601959957143
#   (0, 5066)	0.03620970776782356
#   (0, 11897)	0.06543264929552935
#   (0, 3171)	0.03021278850171473
#   (0, 5048)	0.03334436210961047
#   (0, 7535)	0.03634282174266488
#   (0, 4780)	0.03441224494813315
#   (0, 1714)	0.07166661697038679
#   (0, 14719)	0.07191034367023183
#   (0, 15713)	0.799169373674442
#   (0, 16181)	0.027347442843501636
#   (0, 7246)	0.03037983098650508
#   (0, 13970)	0.03676865999590142
#   (0, 16739)	0.03021278850171473
#   (0, 16738)	0.06345543235739484
#   (0, 7680)	0.06291452337901239
#   (0, 3601)	0.06769086931283556
#   (0, 7709)	0.03005195723305467
#   (0, 14716)	0.1481552774468047
#   (0, 6480)	0.03477294235202492
#   (0, 15316)	0.029989262471282425
#   (0, 13045)	0.03191789462076324
#   (0, 13757)	0.028142905338292133
#   (0, 4435)	0.033696252188757346
#   (0, 12647)	0.020755494131218088
#   :	:
#   (0, 14846)	0.04243481920510297
# ...

# %%
# Import necessary libraries
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.multioutput import ClassifierChain
from sklearn.svm import LinearSVC
from sklearn.preprocessing import MultiLabelBinarizer
import numpy as np



# Function to preprocess the input question
def preprocess_input(text):
    # Implement your preprocessing steps here, such as tokenization, lowercase conversion, etc.
    return text

# Function to predict tags for a given question
def predict_tags(question, vectorizer, classifier_chain, multilabel_binarizer):
    # Preprocess the input question
    question = preprocess_input(question)

    # Vectorize the preprocessed question
    question_vectorized = vectorizer.transform([question])

    # Predict tags using the classifier chain
    predicted_tags = classifier_chain.predict(question_vectorized)

    # Decode predicted tags using multilabel binarizer
    predicted_tags = multilabel_binarizer.inverse_transform(predicted_tags)

    return predicted_tags

# Sample usage
if __name__ == "__main__":
    # Sample input data (you should replace this with your own data loading/preprocessing)
    X_train = ["How to use Python for machine learning?", "What are the best practices for Android development?"]
    y_train = [["python", "machine-learning"], ["android", "development"]]

    # Initialize TF-IDF vectorizer
    vectorizer = TfidfVectorizer()
    X_train_vectorized = vectorizer.fit_transform(X_train)

    # Initialize MultiLabelBinarizer
    multilabel_binarizer = MultiLabelBinarizer()
    y_train_binarized = multilabel_binarizer.fit_transform(y_train)

    # Initialize Classifier Chain
    classifier_chain = ClassifierChain(LinearSVC())
    classifier_chain.fit(X_train_vectorized, y_train_binarized)

    # Get input question from user
    input_question = input("Enter your question: ")

    # Predict tags for the input question
    predicted_tags = predict_tags(input_question, vectorizer, classifier_chain, multilabel_binarizer)

    # Print predicted tags
    print("Predicted Tags:", predicted_tags)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_classes.py:31: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# ...
